# %% [markdown]
# # Desafio Cinematográfico
#
# ## O desafio é desenvolver um programa em Python para registrar os filmes favoritos e as notas que você dá a cada um deles.
#
# - 1
# Solicitar nomes de filmes:
# O usuário informa o nome de um filme e, em seguida, é perguntado
# se deseja cadastrar outro.
# Armazenar os dados:
# Cada nome de filme deve ser gravado em um array com capacidade
# para até 1000 filmes.
# O programa deve impedir a inclusão de filmes repetidos.
#
# Desafio: Cadastro de Filmes e Notas
#
# - 2
# Registrar avaliações:
# Para cada filme informado, o usuário também deverá inserir uma
# nota entre 0.0 e 10.0.
# Essas notas serão armazenadas em um array paralelo.
# Exibir resultados:
# Ao final, quando o usuário decidir parar de cadastrar filmes, o
# programa deverá:
# Listar todos os filmes cadastrados.
# Calcular e exibir a nota média de todos os filmes.

# %%
tamanho = 0
nota_total = 0
def imprime_filmes(filmes):
  for filme in filmes:
    print(f"O filme {filme['nome']} recebeu a nota {filme['nota']} da critica")

def duplicidade(novo, filmes):
  for filme in filmes:
    if novo == filme['nome']:
      return True
    return False

filmes = []

op_string =    "Digite add para adicionar um filme"
op_string += "\n       rm para remover um filme"
op_string += "\n       ed para editar a nota de um filme"
op_string += "\n       sair para sair"

while True:
  print(op_string)
  operacao = input()

  if operacao == "add":
    nome = input("Digite o nome do filme:").strip()
    if nome == "":
      break
    if duplicidade(nome, filmes):
      print("O Filme", nome, "já foi cadastrado")
    else:
      nota = float(input("Digite a nota do filme"))
      tamanho += 1
      nota_total += nota
      filmes.append({'nome': nome, 'nota': nota})
    if tamanho > 1000:
      break
  elif operacao == "rm":
    nome = input("Digite o nome do filme que deseja remover:").strip()
    for filme in filmes:
      if nome == filme['nome']:
        filmes.remove(filme)
        tamanho -= 1
        nota_total -= filme['nota']
        print("Filme", nome, "removido com sucesso")
        break
  elif operacao == "sair":
    print("==========finalizando programa===========")
    break
  elif operacao == "ed":
    nome = input("Digite o nome do filme que deseja editar:").strip()
    for filme in filmes:
      if nome == filme['nome']:
        nota_total -= filme['nota']
        nota = float(input("Digite a nova nota do filme"))
        filme['nota'] = nota
        nota_total += nota
        print("Nota do filme", nome, "alterada com sucesso")
        break
  else:
    print("Operação inválida!")





if tamanho > 0:
  imprime_filmes(filmes)
  print("===========Resumo do catálogo===========")
  print("Possui", tamanho, "filmes e a média das notas é", round(nota_total/tamanho, 1))
  n = len(filmes)
  for i in range(n):
    for j in range(0, n-i-1):
        if filmes[j]['nota'] < filmes[j+1]['nota']:
            filmes[j], filmes[j+1] = filmes[j+1], filmes[j]

  print("\n--- Top 3 Melhores Filmes ---")
  for i in range(min(3, n)):
    print(f"{filmes[i]['nome']} - Nota: {filmes[i]['nota']}")


  n = len(filmes)
  for i in range(n):
    for j in range(0, n-i-1):
        if filmes[j]['nota'] > filmes[j+1]['nota']:
            filmes[j], filmes[j+1] = filmes[j+1], filmes[j]

  print("\n--- Top 3 Piores Filmes ---")
  for i in range(min(3, n)):
    print(f"{filmes[i]['nome']} - Nota: {filmes[i]['nota']}")
  print("===========Programa encerrado===========")
else:
  print("Não possui filmes cadastrados")
# Out:
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# The Office
# Operação inválida!
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:The Office
# Digite a nota do filme10
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Breaking Bad
# Digite a nota do filme10
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Game Of Thrones
# Digite a nota do filme9.8
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Oppenheimer
# Digite a nota do filme9.5
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Black Mirror
# Digite a nota do filme8.0
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Friends
# Digite a nota do filme8.3
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:Daredevil
# Digite a nota do filme7.6
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# add
# Digite o nome do filme:The Good Place
# Digite a nota do filme8.5
# Digite add para adicionar um filme
#        rm para remover um filme
#        ed para editar a nota de um filme
#        sair para sair
# sair
# ==========finalizando programa===========
# O filme The Office recebeu a nota 10.0 da critica
# O filme Breaking Bad recebeu a nota 10.0 da critica
# O filme Game Of Thrones recebeu a nota 9.8 da critica
# O filme Oppenheimer recebeu a nota 9.5 da critica
# O filme Black Mirror recebeu a nota 8.0 da critica
# O filme Friends recebeu a nota 8.3 da critica
# O filme Daredevil recebeu a nota 7.6 da critica
# O filme The Good Place recebeu a nota 8.5 da critica
# ===========Resumo do catálogo===========
# Possui 8 filmes e a média das notas é 9.0
#
# --- Top 3 Melhores Filmes ---
# The Office - Nota: 10.0
# Breaking Bad - Nota: 10.0
# Game Of Thrones - Nota: 9.8
#
# --- Top 3 Piores Filmes ---
# Daredevil - Nota: 7.6
# Black Mirror - Nota: 8.0
# Friends - Nota: 8.3
# ===========Programa encerrado===========
